# %%
pip install ultralytics opencv-python numpy torch torchvision torchaudio labelImg

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt") # Load pre-trained YOLO model
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 131MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model.train(data="/content/drive/MyDrive/yolo/yolo/mydataset/mydata.yaml", epochs=1, imgsz=640, batch=16)
model.save('yolov8n-aditya.pt')
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %%
model = YOLO("yolov8n-aditya.pt") # Load pre-trained YOLO model

# %%
results = model("Stop-Sign-2.jpg")

results[0].show() # Display results
# Out:
# image 1/1 /content/Stop-Sign-2.jpg: 352x640 1 Stop, 7.8ms
# Speed: 2.2ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# <PIL.Image.Image image mode=RGB size=1200x628>

# %%
from ultralytics import YOLO

# Load the custom YOLO model
model = YOLO("yolov8n-aditya.pt")

# Path to the input video
input_video = "/content/333.MP4"

# Run inference on the video and save the output
results = model.predict(source=input_video, save=True, stream= True,imgsz=3840)
for r in results:
        boxes = r.boxes  # Boxes object for bbox outputs
        masks = r.masks  # Masks object for segment masks outputs
        probs = r.probs

print("Inference complete. Output video saved.")
# Out:
# video 1/1 (frame 1/973) /content/333.MP4: 2176x3840 (no detections), 56.9ms
# video 1/1 (frame 2/973) /content/333.MP4: 2176x3840 (no detections), 28.4ms
# video 1/1 (frame 3/973) /content/333.MP4: 2176x3840 (no detections), 28.2ms
# video 1/1 (frame 4/973) /content/333.MP4: 2176x3840 (no detections), 28.4ms
# video 1/1 (frame 5/973) /content/333.MP4: 2176x3840 (no detections), 28.2ms
# video 1/1 (frame 6/973) /content/333.MP4: 2176x3840 (no detections), 28.3ms
# video 1/1 (frame 7/973) /content/333.MP4: 2176x3840 (no detections), 28.2ms
# video 1/1 (frame 8/973) /content/333.MP4: 2176x3840 (no detections), 28.6ms
# video 1/1 (frame 9/973) /content/333.MP4: 2176x3840 (no detections), 28.3ms
# video 1/1 (frame 10/973) /content/333.MP4: 2176x3840 (no detections), 28.3ms
# video 1/1 (frame 11/973) /content/333.MP4: 2176x3840 (no detections), 28.3ms
# video 1/1 (frame 12/973) /content/333.MP4: 2176x3840 (no detections), 28.2ms
# ...
